# %% [markdown]
# #### Selamat datang di analisis pasar kerja untuk posisi analis data! Proyek ini bertujuan untuk membantu kamu memahami pasar kerja dengan lebih baik. Kami akan mengeksplorasi keterampilan apa saja yang paling dicari dan bergaji tinggi, sehingga kamu bisa menemukan peluang kerja terbaik sebagai analis data.📈😉
#
# #### Data yang digunakan berasal dari Kursus Python Luke Barousse yang memberikan dasar untuk analisis saya, mencakup informasi terperinci tentang judul pekerjaan, gaji, lokasi, dan keterampilan penting. Melalui serangkaian skrip Python, saya menganalisa pertanyaan kunci seperti keterampilan yang paling dibutuhkan, tren gaji, dan hubungan antara permintaan dan gaji dalam analitik data.
# #### saya benar-benar bertrimaksih kepada Luke Barousse yang sudah membantu saya😁🙌

# %% [markdown]
# # ***Alat yang Saya Gunakan***

# %% [markdown]
# ### Untuk mendalami pasar kerja analis data, saya memanfaatkan beberapa alat kunci:

# %% [markdown]
# - #### Python: Fondasi dari analisis saya, memungkinkan saya untuk menganalisis data dan menemukan wawasan kritis. Saya juga menggunakan pustaka Python berikut:
# - Pandas Library: Digunakan untuk menganalisis data.
# - Matplotlib Library: Saya gunakan untuk memvisualisasikan data.
# - Seaborn Library: Membantu saya membuat visualisasi yang lebih canggih.

# %% [markdown]
#  - ### Jupyter Notebooks: Alat yang saya gunakan untuk menjalankan skrip Python saya yang memungkinkan saya untuk dengan mudah menyertakan catatan dan analisis.
# - ### Visual Studio Code: Pilihan saya untuk menjalankan skrip Python.
# - ###  Git & GitHub: Penting untuk kontrol versi dan berbagi kode serta analisis Python saya, memastikan kolaborasi dan pelacakan proyek.

# %% [markdown]
# ### Saya memulai dengan mengimpor library yang diperlukan dan memuat dataset, diikuti dengan tugas pembersihan data awal untuk memastikan kualitas data.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')

# %%
df = dataset['train'].to_pandas()
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %% [markdown]
# - #### Kita dapat menggunakan method info() untuk meng-cek seluruh kolom berserta type data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# - #### Berhubungan type data pada kolom ['job_posted_date'] ber-type data object, kita akan ubah terlebih dahulu menjadi datetime untuk kebutuhan analisis

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# - #### Dikarenakan banyak sekali data NaN, kita akan mencoba menghapus data NaN yang ada pada kolom ***['salary_rate']*** menggunakan method dropna.

# %%
df_salary = df.dropna(subset=['salary_rate'])
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %% [markdown]
# - #### Selain menghapus data yang bernilai ***NaN***, kita juga dapat mengisi data yang bernilai NaN dengan sebuah niali rata-rata pada kolom tersebut.
#  - ##### untuk contoh kita akan coba mengisi data yang memilki nilai NaN pada kolom ***['salary_hour_avg']*** dan ***['salary_year_avg']*** berdasarkan nilai rata-rata pada kolom masing-masing

# %%
df_filled = df.copy()
salary_hour_median = df_filled['salary_hour_avg'].median()
salary_year_median = df_filled['salary_year_avg'].median()

df_filled['salary_hour_avg'] = df_filled['salary_hour_avg'].fillna(salary_hour_median)
df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(salary_year_median)

# %%
df_filled.loc[:5, 'salary_year_avg':'salary_hour_avg']
# Out:
#    salary_year_avg  salary_hour_avg
# 0         115000.0            45.98
# 1         115000.0            45.98
# 2         115000.0            45.98
# 3         115000.0            45.98
# 4         115000.0            45.98
# 5         115000.0            45.98

# %% [markdown]
# - #### kemudian cleaning data selanjutnya yaitu menghapus data yang duplikat. kita dapat menggunakan method ***drop_duplicates()***

# %%
df_unique = df_filled
df_unique = df_unique.drop_duplicates()

# %%
print(len(df_unique))
print(len(df_filled))
# Out:
# 785640
# 785741

# %% [markdown]
# - #### Ketika kita menggunakan method ***drop_duplicates()*** aja data yang akan hilang adalah data yang benar-benar memiliki rows dan columns dengan nilai yang sama. maka dari itu saya rasa ini kurang efektif. maka dari itu kita harus memasukan parameter untuk mencari niali duplikat supaya lebih efektif. pada contoh dibawah saya akan mencoba menghapus kolom ***['job_title','company_name']***  yang memiliki nilai yang sama.

# %%
df_unique = df_unique.drop_duplicates(subset=['job_title','company_name'])
print(len(df_unique))
# Out:
# 508042

# %% [markdown]
# - #### Data berhasil dibersihkan, dari sebelumnya 785741 menjadi 508042 rows

# %% [markdown]
# - #### Setelah selesai membersihkan data NaN dan Duplicates, kita akan mencoba menganalisa Negara dengan pekerjaan terbanyak, menggunakn method ***pivot_table()***

# %%
df_plot = df['job_country'].value_counts().to_frame().head(20)

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_country', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Country')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# - #### Salanjutnya kita akan mencoba mencari top 6 country beserta Salary-nya berdasarkan job ***'Data Analyst', 'Data Engineer', 'Data Scientist'***

# %%
top_countries = df['job_country'].value_counts().head(6).index 
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany',
#        'Spain'],
#       dtype='object', name='job_country')

# %% [markdown]
# - #### Setelah mengambil 6 negara dengan job posting terbanyak, selanjutnya kita akan mencari salary-nya

# %%
top_salary_country = df.pivot_table(index='job_country', columns='job_title_short', values='salary_year_avg', aggfunc='median')
top_salary_country
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# ...

# %%
top_salary_country = top_salary_country.loc[top_countries] # mengambil 6 negara terbesar
top_salary_country
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# United States             90000.0        116100.0       90000.0
# India                     64800.0             NaN      100500.0
# United Kingdom            56700.0             NaN       87750.0
# France                    89100.0        105968.0       69175.0
# Germany                   89100.0         89100.0      103750.0
# Spain                     86400.0         89100.0       91977.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# United States         125000.0        130000.0                   150000.0
# India                 147500.0        114008.0                    79200.0
# United Kingdom        110000.0        105300.0                   149653.0
# France                 98301.5         88128.0                    80850.0
# Germany               147500.0        131560.0                    89100.0
# ...

# %%
top_job_titles = df['job_title_short'].value_counts().head(3).index
top_job_titles = top_job_titles.tolist()
top_job = ['Data Analyst', 'Data Engineer', 'Data Scientist']

# %%
top_salary_country = top_salary_country[top_job_titles]
top_salary_country
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# United States         90000.0       125000.0        130000.0
# India                100500.0       147500.0        114008.0
# United Kingdom        87750.0       110000.0        105300.0
# France                69175.0        98301.5         88128.0
# Germany              103750.0       147500.0        131560.0
# Spain                 91977.0       133000.0         88128.0

# %%
top_salary_country.plot(kind='bar')
plt.title('Salary Year AVG')
plt.ylabel('Salary ($)')
plt.xlabel('(Countries)')
plt.show()

# %% [markdown]
# - #### Selanjutnya kita hanya akan menganalisa totol postingan job tiap-tiap bulan hanya di United States

# %%
df_usa = df.copy()

# %% [markdown]
# #### mem-filter pada ***job_country*** hanya United States saja

# %%
df_usa = df[df['job_country']=='United States'].copy()
df_usa
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %% [markdown]
# - #### Membuat kolom ***job_posted_month*** untuk mengambil tiap-tiap bulan dari ***job_posted_date***

# %%
df_usa['job_posted_month'] = df_usa['job_posted_date'].dt.strftime('%B')
df_usa.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9        Data Scientist                                  Data Scientist II
#
#       job_location            job_via         job_schedule_type  \
# 0    Watertown, CT    via Work Nearby                 Full-time
# 3  San Antonio, TX  via Diversity.com                 Full-time
# 5         Anywhere   via ZipRecruiter  Contractor and Temp work
# 6     Dearborn, MI       via LinkedIn                 Full-time
# 9         Anywhere   via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# ...

# %% [markdown]
# - #### Buatkan sebuah ***pivot_tabel*** untuk mempermudah analisa

# %%
df_usa_pivot = df_usa.pivot_table(index='job_posted_month', columns='job_title_short', values='salary_year_avg', aggfunc='size')
df_usa_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %% [markdown]
# - #### Dikarenakan urutan dari bulan pada pivot_table diatas masih berantakan/random, kita rapihkan dengan membuat kolom ***month_numeric***. dimana kita akan membuat bulan juga namun dalam bentuk numerik, sehingga kita dapat mengurutkannya

# %%
df_usa_pivot.reset_index(inplace=True)
df_usa_pivot['month_numeric'] = pd.to_datetime(df_usa_pivot['job_posted_month'], format='%B').dt.month

# %%
df_usa_pivot.sort_values('month_numeric', inplace=True)
df_usa_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 4                        January               527              36
# 3                       February               447              24
# 7                          March               438              19
# 0                          April               565              40
# 8                            May               279              20
# 6                           June               446              32
# 5                           July               581              39
# 1                         August               903              39
# 11                     September               897              50
# 10                       October               932              48
# 9                       November               719              36
# 2                       December               648              40
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_usa_pivot.set_index('job_posted_month', inplace= True)

# %% [markdown]
# - #### Setelah bulan Jan-Dec sudah berurut, maka kita bisa hapus kolom ***month_numeric***, dikarenakan kita sudah tidak membutuhkanya🥲🥲

# %%
df_usa_pivot.drop(columns='month_numeric', inplace=True)

# %%
df_usa_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %% [markdown]
# - #### Kemudian kita buatkan sebuah line chart, untuk mengetahui pekerjaan apa saja yang paling mendominasi selama January - December.

# %% [markdown]
# - ##### Bisa kita lihat bahwasanya, posisi ***Data Analyst*** menjadi yang teratas

# %%
df_usa_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %% [markdown]
# - #### Jika melihat chart seperti itu, sepertinya kurang enak untuk dilihat. coba kita ambil top 3 saja

# %%
top_3 = df_usa['job_title_short'].value_counts().head(3).index
top_3.tolist()
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer']

# %%
df_usa_pivot[top_3].plot(kind='line')
plt.title('Job Demand')
plt.ylabel('Total Job')
# Out:
# Text(0, 0.5, 'Total Job')

# %% [markdown]
# - #### Selanjutnya kita akan mencoba seberapa signifikan total job posting pada Quartal pertama (Jan-Mar)

# %% [markdown]
# - ##### buatkan bulan seperti sebelumnya

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %% [markdown]
# - ##### Ambil bulan-nya saja untuk kebutuhan analisa

# %%
months = df['job_posted_month'].unique()
months
# Out:
# array(['Jun', 'Jan', 'Oct', 'Jul', 'Aug', 'Nov', 'Mar', 'Dec', 'Apr',
#        'Feb', 'Sep', 'May'], dtype=object)

# %%
# {month: month for month in months} # dikarenakan key dan value nya bukan sebuah dataframe kita ubah kodenya

# %% [markdown]
# - #### Pada kode dibawah kita sudah membuat variabel ***dict_month*** dimana ketika kita membuat variabel beserta nama kolom bulan-nya maka secara otomatis akan terfilter berdasarkan bulan tersebut.
#
# ##### Pada contoh dibawah saya mencoba menggunakan bulan ***Jan*** Untuk contohnya

# %%
dict_month = {month : df[df['job_posted_month']==month] for month in months}
dict_month['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %% [markdown]
# - #### Kemudian kita gabung Jan-Mar menggunkaan ***Method() Concat*** (Quarter 1)

# %%
df_q1 = pd.concat([dict_month['Jan'],dict_month['Feb'],dict_month['Mar']],ignore_index=True)
df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
sns.set_theme(style='darkgrid')
df_q1['job_posted_month'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.title('First Quarter')
plt.ylabel('Total job Posted')
plt.xlabel('Job Posted Month')
plt.show()

# %% [markdown]
# - ### Kita akan membuat sebuah sekenario, bahwa inflasi pada tahun 2023 ini adalah 3%. maka berapakah total inflasi dalam bentuk uang-nya

# %% [markdown]
# #### menghapus nilai NaN pada kolom ***salary_year_avg***

# %%
df[pd.notna(df['salary_year_avg'])]['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %% [markdown]
# ##### membuat inflasi sebesar 3% dari salary year menggunakan fungsi dari method() ***apply(***)

# %%
df_salary = df
df_salary = df[pd.notna(df['salary_year_avg'])].copy()

def inflation (salary):  # membuat function untuk membuat inflasi tahun 2023 adalah 3%
    return salary * 0.03

df_salary['inflation_per_year'] = df_salary['salary_year_avg'].apply(inflation)
df_salary[['salary_year_avg','inflation_per_year']]
# Out:
#         salary_year_avg  inflation_per_year
# 28             109500.0             3285.00
# 77             140000.0             4200.00
# 92             120000.0             3600.00
# 100            228222.0             6846.66
# 109             89000.0             2670.00
# ...                 ...                 ...
# 785624         139216.0             4176.48
# 785641         150000.0             4500.00
# 785648         221875.0             6656.25
# 785682         157500.0             4725.00
# 785692         157500.0             4725.00
#
# [22003 rows x 2 columns]

# %% [markdown]
# ### pada kolom ***job_skills*** walaupun bentuknya seperti list, namun ketika kita coba cek type datanya, ternaya adalah type str, lalu kita akan merubah-nya dari type str menjadi list

# %%
type(df['job_skills'])
# Out:
# pandas.core.series.Series

# %%
import ast
type(ast.literal_eval(df['job_skills'][1]))
# Out:
# list

# %%
# cara 1
# def clean_list(skills_list): # membuat function untuk digunakan pada function apply
#     if pd.notna(skills_list): # menghapus none values
#         return ast.literal_eval(skills_list)

# df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
type(df['job_skills'][1])
# Out:
# str

# %%
# cara kedua
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

# %%
type(df['job_skills'][1])
# Out:
# list

# %% [markdown]
# #### Pada analisa sebelumnya, bahwasanya pada tahun 2023 terkena inflase sebesar 3%, namun kita akan membuat job_title_short yang memiliki kata 'Senior' akan mendapatkan inflasi sebesar 5%, sedangkan lainya hanya 3%

# %%
def project_salary(row):
    if "Senior" in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']
    
df_salary['inflation_per_year'] = df_salary.apply(project_salary, axis=1)

# %%
df_salary[['job_title_short','salary_year_avg','inflation_per_year']]
# Out:
#        job_title_short  salary_year_avg  inflation_per_year
# 28      Data Scientist         109500.0           112785.00
# 77       Data Engineer         140000.0           144200.00
# 92       Data Engineer         120000.0           123600.00
# 100     Data Scientist         228222.0           235068.66
# 109       Data Analyst          89000.0            91670.00
# ...                ...              ...                 ...
# 785624   Data Engineer         139216.0           143392.48
# 785641   Data Engineer         150000.0           154500.00
# 785648  Data Scientist         221875.0           228531.25
# 785682  Data Scientist         157500.0           162225.00
# 785692  Data Scientist         157500.0           162225.00
#
# [22003 rows x 3 columns]

# %% [markdown]
# ## Selanjutnya kita akan mencari job skills terbanyak, diakrenakan pada kolom job_skills masih dalam bentuk list.lita dapat memecahnya menggunakan ***Explode()*** method

# %% [markdown]
# Metode explode dalam library pandas di Python digunakan untuk mengubah elemen-elemen yang berisi list atau array dalam DataFrame menjadi baris-baris terpisah. Ini sangat berguna ketika Anda memiliki kolom yang berisi list dan Anda ingin 'memperluas' list tersebut sehingga setiap elemen dalam list menjadi baris tersendiri.

# %% [markdown]
# ### Terapkan ke df asli

# %%
df_exploded_ori = df.explode('job_skills')
df_exploded_ori.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 1          Data Analyst                                       Data Analyst
# 1          Data Analyst                                       Data Analyst
# 1          Data Analyst                                       Data Analyst
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
sns.set_theme(style='dark')
df_exploded_ori['job_skills'].value_counts().head(10).plot(kind='barh')
plt.ylabel('Job Skills')
plt.xlabel('Total Job Skills')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# #### kita bisa lihat bahwa SQL berada paling teratas untuk pemintaan berdasarkan kolom job_skills

# %% [markdown]
# ## Sekarang kita akan mencari job title berdasarkan 'Data Analyst'

# %%
df_exploded_ori.groupby(['job_title_short','job_skills']).size()
# Out:
# job_title_short    job_skills
# Business Analyst   airflow        318
#                    airtable        17
#                    alteryx       1078
#                    angular         87
#                    ansible        120
#                                  ...
# Software Engineer  wrike            4
#                    wsl             13
#                    xamarin         35
#                    yarn           145
#                    zoom           229
# Length: 2256, dtype: int64

# %%
explode_data_analyst = df_exploded_ori.groupby(['job_title_short','job_skills']).size().reset_index()
type(explode_data_analyst)
# kita akan merubah 'pandas.core.frame.DataFrame' menjadi dataframe dengan cara reset index
# Out:
# pandas.core.frame.DataFrame

# %%
explode_data_analyst = df_exploded_ori.groupby(['job_title_short','job_skills']).size().sort_values(ascending=False).reset_index(name='job_count')
explode_data_analyst
# Out:
#             job_title_short   job_skills  job_count
# 0            Data Scientist       python     113711
# 1             Data Engineer          sql     113130
# 2             Data Engineer       python     108022
# 3              Data Analyst          sql      92428
# 4            Data Scientist          sql      78982
# ...                     ...          ...        ...
# 2251         Cloud Engineer       delphi          1
# 2252  Senior Data Scientist  objective-c          1
# 2253    Senior Data Analyst      couchdb          1
# 2254         Cloud Engineer      haskell          1
# 2255           Data Analyst         suse          1
#
# [2256 rows x 3 columns]

# %%
job_title = 'Data Analyst' # kita dapat merubahnya menjadi data engineer dll.
top10 = 10
final_data_analyst_count = explode_data_analyst[explode_data_analyst['job_title_short']==job_title].head(top10)

sns.set_theme(style='ticks')
sns.barplot(data=final_data_analyst_count, x='job_count', y='job_skills', hue='job_count', palette='mako_r')
plt.legend('')
plt.title(f'{top10} Skills for {job_title}',fontweight='bold')
plt.ylabel('')
plt.xlabel('(Total)',fontweight='bold')
plt.show()

# %% [markdown]
# ### Saya akan membuat grafik dengan top 5 Trending Skills

# %%
df_pivot_DA = df_exploded_ori
df_pivot_DA['job_posted_month2'] = df_pivot_DA['job_posted_date'].dt.month 
df_pivot_DA.pivot_table(index='job_posted_month2', columns='job_skills', aggfunc='size', fill_value=0)
# Out:
# job_skills         airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month2
# 1                     5136        36     1509      677          19      965
# 2                     3709        15     1150      447          14      696
# 3                     3876        14     1092      415          16      757
# 4                     3805        17     1068      491          14      726
# 5                     3480        24      857      358           7      526
# 6                     3810        31     1060      398          10      608
# 7                     3685        21     1015      406           4      634
# 8                     4035        34     1175      554           4      761
# 9                     3289        18      923      366           7      564
# 10                    3717        33      928      430          10      605
# 11                    3555        33      838      422           9      565
# ...

# %% [markdown]
# ### membuat ***ROW Total*** untuk menjumlahkan total dari semua bulan (Jan-Dec) dan ambil 5 terbesar

# %%
df_DA = df_pivot_DA.pivot_table(index='job_posted_month2', columns='job_skills', aggfunc='size', fill_value=0)
df_DA.loc['Total'] = df_DA.sum()
df_DA = df_DA[df_DA.loc['Total'].sort_values(ascending=False).head().index]
df_DA
# Out:
# job_skills            sql  python     aws   azure       r
# job_posted_month2
# 1                   45774   44889   16805   15385   16351
# 2                   32720   31943   12219   11114   11288
# 3                   32282   31990   12458   11152   11358
# 4                   31096   30482   11635   10557   10647
# 5                   27096   26908   10394    9111    9339
# 6                   31671   31216   11759   10793   10820
# 7                   31869   31257   12017   10960   10793
# 8                   36699   36228   13817   12193   13037
# 9                   28926   28616   10934   10221    9248
# 10                  30743   30590   11638   10923    9990
# 11                  29864   30112   11439   10681    9654
# 12                  26109   26678   10266    9437    8367
# Total              384849  380909  145381  132527  130892

# %% [markdown]
# #### kita bisa hapus row ***[Total]*** dikarenakan sudah tidak dibutuhkan lagi

# %%
df_DA = df_DA.drop('Total')
df_DA
# Out:
# job_skills           sql  python    aws  azure      r
# job_posted_month2
# 1                  45774   44889  16805  15385  16351
# 2                  32720   31943  12219  11114  11288
# 3                  32282   31990  12458  11152  11358
# 4                  31096   30482  11635  10557  10647
# 5                  27096   26908  10394   9111   9339
# 6                  31671   31216  11759  10793  10820
# 7                  31869   31257  12017  10960  10793
# 8                  36699   36228  13817  12193  13037
# 9                  28926   28616  10934  10221   9248
# 10                 30743   30590  11638  10923   9990
# 11                 29864   30112  11439  10681   9654
# 12                 26109   26678  10266   9437   8367

# %% [markdown]
# ### buat sebuah line chart

# %%
months = [
    "Jan",
    "Feb",
    "Mar",
    "Apr",
    "May",
    "Jun",
    "Jul",
    "Aug",
    "Sep",
    "Oct",
    "Nov",
    "Dec"
]
df_DA.iloc[:12,:5].plot(kind='line', marker='o', linewidth=2, colormap='cividis')
plt.xticks(ticks=range(12),labels=months)

plt.show()

# %% [markdown]
# #### bisa kita lihat bahwa ***SQL*** dan ***Python*** ada dipaling teratas

# %% [markdown]
# ### Jika kita perhatikan, ***Data Analyst, Data Engineer dan Data Scientis***t adalah job dengan postingan terbanyak. maka saya akan saya coba analisa  5 skills apa saja yang paling dibutuhkan untuk job dalam kireteria tersebut.

# %%
df_skills = df.copy()
df_skills = df_skills.explode('job_skills')
skills_count = df_skills.groupby(['job_skills','job_title_short']).size()
skills_count
# Out:
# job_skills  job_title_short
# airflow     Business Analyst               318
#             Cloud Engineer                 260
#             Data Analyst                  2002
#             Data Engineer                25505
#             Data Scientist                3915
#                                          ...
# zoom        Machine Learning Engineer       46
#             Senior Data Analyst             86
#             Senior Data Engineer           122
#             Senior Data Scientist           79
#             Software Engineer              229
# Length: 2256, dtype: int64

# %%
df_skills_count = skills_count.reset_index(name="skill_count")
df_skills_count = df_skills_count.sort_values(by='skill_count', ascending=False)
df_skills_count
# Out:
#       job_skills            job_title_short  skill_count
# 1480      python             Data Scientist       113711
# 1822         sql              Data Engineer       113130
# 1479      python              Data Engineer       108022
# 1821         sql               Data Analyst        92428
# 1823         sql             Data Scientist        78982
# ...          ...                        ...          ...
# 2173       webex      Senior Data Scientist            1
# 1054  mattermost             Data Scientist            1
# 270      clickup  Machine Learning Engineer            1
# 797       heroku        Senior Data Analyst            1
# 1128    msaccess               Data Analyst            1
#
# [2256 rows x 3 columns]

# %%
job_titles = ['Data Analyst','Data Scientist','Data Engineer']
fig, ax = plt.subplots(3,1, figsize=(10,8))
sns.set_theme(style='whitegrid')

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_count[df_skills_count['job_title_short']==job_title].head()
    df_plot.plot(kind='barh', x='job_skills',y='skill_count', ax=ax[i], title=job_title)
    ax[i].invert_yaxis()
    ax[i].legend('')
    ax[i].set_ylabel('')
    ax[i].set_xlim(0, 120000)

fig.suptitle('TOP SKILLS IN JOB POSTINGS', fontsize=15)
fig.tight_layout()

# %% [markdown]
# #### bisa kita lihat bahwa ***SQL*** dan ***Python*** ada disetiap jobs. dan ini berarti bahwa ***SQL*** dan ***Pyhton*** sangatlah penting dalam urusan ***DATA***

# %% [markdown]
# ## Kita akan melihat berapa persen pekerjaan yang ***Work From Home*** dan pekerjaan yang ***Non Work From Home***

# %%
df['job_work_from_home'].value_counts(ascending=False).plot(kind='pie', startangle=90, autopct="%1.1f%%")
plt.ylabel('')
plt.title('WFH Status')
# Out:
# Text(0.5, 1.0, 'WFH Status')

# %% [markdown]
# ### bisa kita lihat Perbandingan ***WFH*** dan ***Non WFH*** berbeda sangatlah jauh, ini dikarenakan Pandemi Covid-19 sudah mulai berakhir, sehingga banyak perusahaan yang ingin merekrut karyawan dan bekerja di kantor.

# %% [markdown]
# #### Data ini diambil berdasarkan tahun 2023, nah saya akan coba menampilkan berapa persen total dari masing-masing jobs yang ada didalam job posting ini pada tahun 2023

# %%
df['job_title_short'].value_counts(ascending=False).plot(kind='pie', wedgeprops=dict(width=0.5), autopct='%1.1f%%',textprops={'fontsize': 10})
plt.ylabel('')
plt.title('Job Titles', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Job Titles')

# %% [markdown]
# #### Job Oportunities apa saja yang ditawarkan oleh perusahaan-perusahaan, kita akan coba menampilkan-nya dalam 3 in 1 menggunakan ***Method Subplots***

# %%
fig, ax = plt.subplots(1,3, figsize=(15,8))
dict_columns = {
                'job_work_from_home': 'WFH Status',
                'job_no_degree_mention': 'Job No Degree',
                'job_health_insurance': 'Health Insurance'}

for i,(column, title) in enumerate(dict_columns.items()):
    ax[i].pie(df[column].value_counts(), autopct='%1.1f%%', labels=['False','True'], wedgeprops=dict(width=0.5),startangle=90)
    ax[i].set_title(title, fontweight='bold')

# %% [markdown]
# ### Kemudian saya akan menggunakan fungsi dari Scatter_plot, dimana dapat kita gunakan untuk menunjukan hubungan 2 variabel, dimana variabel yang saya maksud disini adalah ****skill yang paling banyak digunakan berserta salary-nya**** berdasarkan pekerjaan Data Analyst

# %%
df_scatter = df[df['job_title_short']=='Data Analyst']
df_scatter_explode = df_scatter.explode('job_skills')
df_scatter_explode.head()
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
# ...

# %%
df_scatter_explode.groupby('job_skills').agg(
    skill_count = ('job_skills','count'),
    median_salary = ('salary_year_avg', 'median')
)
# Out:
#             skill_count  median_salary
# job_skills
# airflow            2002       111175.0
# airtable             88        90000.0
# alteryx            4570       105000.0
# angular             376       109101.0
# angular.js            2            NaN
# ...                 ...            ...
# wrike                39        75000.0
# wsl                  16            NaN
# xamarin               2            NaN
# yarn                 76        99150.0
# zoom                465        81167.0
#
# [235 rows x 2 columns]

# %%
df_stats = df_scatter_explode.groupby('job_skills').agg(
    skill_count = ('job_skills','count'),
    median_salary = ('salary_year_avg', 'median')
)
df_stats.sort_values(by='skill_count',ascending=False).head(10)
# Out:
#             skill_count  median_salary
# job_skills
# sql               92428        92500.0
# excel             66860        84479.0
# python            57190        98500.0
# tableau           46455        95000.0
# power bi          39380        90000.0
# r                 29996        92527.5
# sas               27998        90000.0
# powerpoint        13822        85000.0
# word              13562        80000.0
# sap               11280        90000.0

# %%
df_stats = df_stats.sort_values(by='skill_count',ascending=False).head(10)
colors = [
    "#FF5733",  # Orange Red
    "#33FF57",  # Lime Green
    "#3357FF",  # Blue
    "#FF33A1",  # Hot Pink
    "#F3FF33",  # Yellow
    "#33F4FF",  # Cyan
    "#FF9D33",  # Light Orange
    "#8D33FF",  # Purple
    "#33FFB5",  # Aquamarine
    "#FF3333"   # Red
]
sns.set_theme(style='whitegrid')
df_stats.plot(kind='scatter', x='skill_count', y='median_salary', color=colors)
plt.xlabel('Skill Count')
plt.ylabel('Median Salary ($USD)')

for i,txt in enumerate(df_stats.index):
    # print(i,txt)
    plt.text(df_stats['skill_count'].iloc[i], df_stats['median_salary'].iloc[i], txt)

# mengubah format yaxis
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${y/1000}k'))

# mengubah format xaxis
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))

# %% [markdown]
# ### saya akan menganalisa seberapa besar dan sering salary_year_avg ditawarkan oleh perusahaan, dan berdasarkan posisi ***Data Analyst*** dan hanya pada job_country = ***'United States'***. kita akan menganalisanya menggunakan ***Histogram***

# %%
df_hist = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country']=='United States')].copy()
df_hist['salary_year_avg'].plot(kind='hist', bins=30, edgecolor='#000000')

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${x/1000}K'))
plt.xlabel('(Yearly Salary)')
plt.xlim(0, 250000)
plt.title('Distribution of United States Data Analyst Yearly Salaries')
# Out:
# Text(0.5, 1.0, 'Distribution of United States Data Analyst Yearly Salaries')

# %% [markdown]
# #### bisa kita lihat bahwa salary pada range $70k - $90k lah yang paling banyak ditawarkan oleh perusahaan-perusahaan. dengan Frequency antara 650-750

# %% [markdown]
# ### Lalu kemudian kita akan mencari nilai minimum, average dan maksimal pada kolom salary_year_avg menggunakan ***Box Plots***. Box Plots ini sendiri memberikan gambaran umum tentang distribusi data, termasuk median, kuartil, dan rentang data. Ini membantu dalam memahami bagaimana data terdistribusi dan apakah ada outlier.

# %%
job_titles = ['Data Analyst','Data Engineer', 'Data Scientist']
df_box = df[(df['job_title_short'].isin(job_titles)) & (df['job_country']=='United States')].copy()

df_box = df_box.dropna(subset=['salary_year_avg'])

df_box_list = [df_box[df_box['job_title_short']==job_title]['salary_year_avg'] for job_title in job_titles]
df_box_list
# Out:
# [109        89000.0
#  180        90250.0
#  410       133285.0
#  988        62623.0
#  1413       71300.0
#              ...
#  782637     70000.0
#  782798    111175.0
#  783588    125000.0
#  783866    115000.0
#  784882     87500.0
#  Name: salary_year_avg, Length: 4350, dtype: float64,
#  92        120000.0
#  146       129500.0
#  307       185000.0
#  339       195000.0
#  380        97500.0
#              ...
#  783111    125000.0
#  784102     90000.0
#  784191    217500.0
#  785624    139216.0
#  785641    150000.0
#  Name: salary_year_avg, Length: 2915, dtype: float64,
#  100       228222.0
#  116       114000.0
#  257       103128.0
#  450       157500.0
#  1257       70700.0
#              ...
#  785324    234500.0
#  785488    115000.0
#  785563    136400.0
#  785648    221875.0
#  785692    157500.0
#  Name: salary_year_avg, Length: 4553, dtype: float64]

# %%
sns.boxplot(data=df_box, x='salary_year_avg', y='job_title_short')
plt.xlabel('(Salary Yearly)')
plt.ylabel('')
plt.title('Salary Distribution in the United States')
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))
plt.show()

# %% [markdown]
# ### Selanjutnya kita akan mencari TOP 10 Salary Tertinggi, dan TOP 10 job skills dengan permintaan terbanyak berserta Salary-nya

# %% [markdown]
# ##### mencari top salary dan top demand skills beserta salary-nya

# %%
df_final = df_hist
df_final = df.explode('job_skills')
df_final= df_final[['job_skills','salary_year_avg']]
df_final = df_final.dropna(subset=['salary_year_avg'])
df_final
# Out:
#         job_skills  salary_year_avg
# 28            gdpr         109500.0
# 28           excel         109500.0
# 77         mongodb         140000.0
# 77         mongodb         140000.0
# 77          python         140000.0
# ...            ...              ...
# 785682     airflow         157500.0
# 785682  kubernetes         157500.0
# 785692      python         157500.0
# 785692      matlab         157500.0
# 785692           r         157500.0
#
# [120719 rows x 2 columns]

# %%
df_final.groupby('job_skills')['salary_year_avg'].agg(['count','median'])
# Out:
#             count         median
# job_skills
# airflow      1497  147090.500000
# airtable       22  102500.000000
# alteryx       386  115000.000000
# angular       113  130000.000000
# angular.js      2  127050.000000
# ...           ...            ...
# workfront       8   93480.054688
# wrike           2  101250.000000
# xamarin         2  121250.000000
# yarn           57   96773.000000
# zoom           79  121500.000000
#
# [219 rows x 2 columns]

# %%
df_final_groupby = df_final.groupby('job_skills')['salary_year_avg'].agg(['count','median'])

df_final_top_pay = df_final_groupby.sort_values(by='median',ascending=False).head(10)
df_final_top_pay
# Out:
#               count    median
# job_skills
# debian            1  196500.0
# ringcentral       2  182500.0
# mongo           256  173500.0
# lua               1  170500.0
# watson           31  157500.0
# dplyr            19  157500.0
# haskell           3  157500.0
# hugging face     37  157500.0
# asp.net core      1  155000.0
# solidity         10  152500.0

# %%
df_final_top_demand = df_final_groupby.sort_values(by='count', ascending=False).sort_values(by='count', ascending=False)
df_final_top_demand = df_final_top_demand.head(10).sort_values(by='median', ascending=False)
df_final_top_demand
# Out:
#             count    median
# job_skills
# spark        4016  140000.0
# aws          4949  135000.0
# java         2756  134241.0
# python      12869  125000.0
# azure        3466  125000.0
# sql         12951  120000.0
# r            5088  119550.0
# tableau      4814  111175.0
# sas          3132  110000.0
# excel        3822   92500.0

# %%
fig, ax = plt.subplots(2,1, figsize=(10,8))
sns.set_theme(style='ticks')

sns.barplot(data=df_final_top_pay, x='median', y=df_final_top_pay.index, ax=ax[0], hue='median', palette="dark:#5A9_r")
ax[0].set_title('Top 10 Higest salary Skills for Data Analyst')
ax[0].set_ylabel('')
ax[0].set_xlabel('(Median Salary)')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))
ax[0].legend().remove()

sns.barplot(data=df_final_top_demand, x='median', y=df_final_top_demand.index, ax=ax[1], hue='median', palette='light:b')
ax[1].set_title("Top 10 Higest demand & it's salary Skills for Data Analyst")
ax[1].set_ylabel('')
ax[1].set_xlabel('(Median Salary)')
ax[1].set_xlim(ax[0].get_xlim())
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))
ax[1].legend().remove()

fig.tight_layout()

# %% [markdown]
# ### Mencari Perusahaan dengan Job Postings terbanyak

# %%
df_companies = df['company_name'].value_counts().to_frame()[1:].head(20)

sns.set_theme(style='ticks')
sns.barplot(data=df_companies, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Company')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Job Location
# - #### mencari lokasi-lokasi pada job posting

# %%
df_location = df['job_location'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_location, x='count', y='job_location', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Job Locations for Data Analyst in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()
